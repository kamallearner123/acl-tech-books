# %%
# Program 1.2: Interactive User Input & Formatting
user_name = "kamal"#input("Enter your developer handle: ")
experience_years = 3

print(f"Welcome, {user_name}! You have {experience_years} years of Python experience.")

user_name = "Khaja"#input("Enter your developer handle: ")
experience_years = 3

print(f"Welcome, {user_name}! You have {experience_years} years of Python experience.")
# Out:
# Welcome, kamal! You have 3 years of Python experience.
# Welcome, Khaja! You have 3 years of Python experience.

# %%
user_names = ["kamal", "khaja"]
experience_years = 3

for name in user_names:
    print(f"Welcome, {name}! You have {experience_years} years of Python experience.")
# Out:
# Welcome, kamal! You have 3 years of Python experience.
# Welcome, khaja! You have 3 years of Python experience.

# %%
for num in range(0,10,2):
    print(num)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
news = '''

Bengaluru  26°CWeather NewsSeptember 19, 2026e-Paper

The Hindu Logo

Search
India
World
Sport
Asian Games
Data
Health
Opinion
Science
Premium
India will look to shooter Manu Bhaker to lead India’s medal charge after her exploits at the Paris Olympics 2024.
Asian Games 2026 | Time for India’s athletes to make it count
‘Technologies that once arrived in India through imports are increasingly being invented at home through local research institutions, industry, and startups’
A homegrown innovation ecosystem is taking root

What masculinity really means
Jama Masjid in Old Delhi, built by Mughal emperor Shah Jahan, between 1644 and 1656.
Delhi is many cities, and this website can help you navigate them all
In 2025, Sukhvinder Pal Singh received the Australian Institute of Food Science and Technology’s national Food Safety Award.
India needs a risk-based approach to food adulteration: Sukhvinder Pal Singh
An illustration from Nivaala’s recipe journal
Meet the people keeping India’s culinary memories alive
Top News

Live
Asian Games 2026 LIVE: Opening ceremony under way in Japan
The 20th Asian Games opens in Nagoya; Manu Bhaker and Pawan Sehrawat lead the Indian contingent
The Hindu Bureau
Live Updates
Games officially declared open
Host Japan enters
Olympic Council of Asia president says politics have already entered into the Asian Games
West Bengal Police also said that Milan Pradhan was absconding and had been evading the due process of the law for almost 19 years. File
West Bengal
Arrest of Nandigram Congress candidate lawful step: Police
Shrabana Chatterjee
Leader of the Opposition in the Lok Sabha, Rahul Gandhi. File.
Madhya Pradesh
‘Jhooth Ki Goonj’ posters surface in Indore ahead of Rahul Gandhi’s student event
PTI
Sikkim
Nepal disaster impact: Sikkim High Court initiates PIL on climate justice
The Hindu Bureau
CMRL pay-off case
Keralam Advocate General recommends FIR registration against former CM Pinarayi, kin
K.S. Sudhi
Delhi
DUSU counting: ABVP dominance under duress, show initial trends
Ashna Butani
World
What does the new U.S.-Denmark deal over Greenland entail, after Trump’s takeover threats?
The Hindu Bureau
World
Trump signs Russia sanctions bill into law
Agencies
Karnataka
With southern States in the same boat, Karnataka turns to Assam for power
Rashmi Patil
Customers at HandpickedByPC farmers’ market
Features
A pantry with a past: Indian consumers are seeking indigenous, organic produce
Satarupa Paul
English
No hard ceilings: On the revision to EPFO wage ceiling
Continental glory: On the Asian Games 2026
READ OUR EDITORIALS IN

Lead
A homegrown innovation ecosystem is taking root 
Mukundan Chakrapani,Gaurav Jain
‘Technologies that once arrived in India through imports are increasingly being invented at home through local research institutions, industry, and startups’
T.C.A. Sharad Raghavan,Kallol Bhattacherjee
Cities
Select City
Bengaluru
SIR: While people struggle to get notices, CEO says nearly 80% delivered
Till September 11, 24.97 lakh, or 56%, of the notices had been delivered.
After viral gridlock, traffic police and residents begin road repair at Whitefield
Repair work being taken up by traffic police on Gunjur-Varthur stretch in Bengaluru on Friday.
States
Select State
Karnataka
Union Home Minister Amit Shah falls ill in Hubballi, skips inauguration of college
A file photo of Union Home Minister Amit Shah who is on a visit to Hubballi to attend a private event scheduled on September 19, 2026.
Power outage complaints pour in from across State
Many residents also complained of not being able to reach the Bescom helpline to access information.
Three persons arrested for murder of father-daughter in gram panchayat office in Belagavi district
The accused allegedly picked up a quarrel with the victims over a property before attacking them with sickles and stones. 
The Hindu Explains
What are the alternatives to SWIFT, and how are they faring? Explained 
Multiple wars and U.S. weaponisation of the dollar through financial sanctions are making countries in the Global South think of bypassing the so-far universally accepted SWIFT system for inter-country payments
G R Rajeev
Multiple wars and U.S. weaponisation of the dollar through financial sanctions are making countries in the Global South think of bypassing the so-far universally accepted SWIFT system for inter-country payments.
How are noisy celebrations and DJs affecting our hearing? 
A new research paper published in Scientific Reports in January 2026 uses the term ‘subclinical hearing damage’ to identify the effect on hearing due to high-level amplified music at recreational/celebratory events. Photo for representative purposes
Why the Tata Sons Board and majority-owner Tata Trusts are in conflict | Explained 
Combined file image of N. Chandrasekaran (L) and Noel Tata (R).
Can a Muslim minor marry under personal law? What courts have said | Explained 
For representative purposes.
More stories
Science
A view of Pneumocystis jiroveci fungi under a microscope.
Fungus found evolving resistance to drug meant for humans 
Vasudevan Mukunth
‘Science should not merely open new frontiers for exploitation; it should also reveal which frontiers are best left untouched’
Balancing deep-sea discovery with environmental stewardship 
P. Ragavan
The analysis shows statistically significant positive associations between short-term exposure to PM2.5 and PM10, long-term exposure to PM2.5 and NO2, and risk of death by suicide, attempted suicide and suicide ideation,” the authors wrote |Image used for representational purpose only
Study links air pollution to death by suicide, suicidal thoughts
PTI
The speech, peppered with questions about long established vaccine safety, also highlighted how once fringe views on vaccines have been given a prominent pulpit under the Trump administration
Kennedy tells anti-vaccine activists they have a friend in Trump’s White House
AP
Featured Videos
Videos Shows Webinars Shorts

ECI gives rival Trinamool factions new names, symbols; what does this mean for Mamata? | Above the Fold | Sept 18, 2026

ECI gives rival Trinamool factions new names, symbols; what does this mean for Mamata? | Above the Fold | Sept 18, 2026

Watch: U.S. sanctions on Russian oil: What are India’s options? | Worldview

Nandigram bypoll: Congress candidate arrested, party questions police action

Watch: Why are these Paniya families still living in tents seven years after Kerala floods?
View all videos
Movie reviews
Nicole Kidman and Sandra Bullock in ‘Practical Magic 2’
‘Practical Magic 2’ review: Sandra Bullock and Nicole Kidman provide the enchantment in bland sequel
Mini Anthikad Chhibber
Monisha and Vinay Rajkumar in ‘City Lights’.
‘City Lights’ review: Sinking into a bottomless pit
Vivek M.V.
Fact, fiction and flying objects: This new docufiction journeys across prehistory, colonial records and UFO encounters in Pavagada
A still from the film
Movies
Tamil, friendship and music: The many lives of Hiphop Tamizha Adhi
Hiphop Tamizha Adhi
Movies
‘Premalu’, ‘Bethlehem Kudumba Unit’ makers announce next film titled ‘Picnic’
The poster of ‘Picnic’
Sport
Sport
Olympic Council of Asia president says politics have already entered into the Asian Games
Sheikh Joaan bin Hamad Al Thani, president of the Olympic Council of Asia, speaks during a press conference in Nagoya, central Japan.
Sport
Indians living in Japan on stand-by to house Asian Games athletes
Italian cruise ship Costa Serena, which will serve as a floating temporary athletes' village for 4,000 to 5,000 participants during the Aichi-Nagoya 2026 Asian Games, docked at the port of Nagoya, Japan.
Sport
Prannoy says Aichi-Nagoya likely his last Asian Games, keeps LA 2028 door open
This is probably my last Asian Games. I don’t think I will be able to play at this level after four years. I only want to play at that level, not lower, H.S. Prannoy said. File Photo
Health
Karnataka
A dangerous dose of deception in Karnataka and beyond 
The private farmhouse on the outskirts of C.K. Tandya village that was allegedly being used as a counterfeit drug repackaging and re-labelling facility.
Health
All you need to know about: nosebleeds 
Common causes of a nosebleed include the inside of the nose becoming dry, usually due to a change in temperature, picking the nose, or blowing the nose too hard
Mumbai
71% consumers in Mumbai rarely asked for prescription, survey finds; Maharashtra FDA acted against 880 drug licensees in three months
People making purchases at the chemist shop. File
Science
Science
How are noisy celebrations and DJs affecting our hearing? 
A new research paper published in Scientific Reports in January 2026 uses the term ‘subclinical hearing damage’ to identify the effect on hearing due to high-level amplified music at recreational/celebratory events. Photo for representative purposes
Science
Fungus found evolving resistance to drug meant for humans 
A view of Pneumocystis jiroveci fungi under a microscope.
Science
NASA scan discovers new, ‘once in a century’ Moon crater
This picture, taken by NASA’s Lunar Reconnaissance Orbiter Camera, shows a new crater on the Moon’s surface.
Books
Art
At ‘Unbound’ art exhibition in Thiruvananthapuram, the mortal and the magical mingle
Mary Samual with paintings at the art exhibition in Alliance Française de Trivandrum, Vazhuthacaud.
Reviews
Review | ‘The River of Grey Flowers’ by Rejimon Kuttappan takes readers inside a scam centre
Workers rescued from scam centres in Myanmar wait at a detention facility in February 2025.
Authors
Interview | Kathryn Stockett returns with new novel 17 years after ‘The Help’ 
Author Kathryn Stockett; and (right) a poster of ‘The Help’, the movie adaptation of Stockett’s debut novel.
Education
Education
UWA opens Mumbai Campus; MBA course to commence from November
Maharashtra Chief Minister Devendra Fadnavis poses for a photograph during the inauguration and unveiling of the commemorative plaque of the University of Western Australia India (UWA) Mumbai Campus, in Mumbai on Friday. Photo: @CMOMaharashtra X/ANI Photo
Education
Can Indian universities close the AI ethics gap?
AI education needs to factor in ethical code of conduct for proper implementation and use at an early stage.
Education
What are the four pillars of academic excellence?
Institutions must move beyond their traditional role as centres of instruction and evolve into centres of discovery, innovation, and intellectual leadership.
Food
Society
India needs a risk-based approach to food adulteration: Sukhvinder Pal Singh 
print(freq)
# Out:
# 36

# %%
# Unsupervised Learning: K-Means Clustering
# We have coordinates of data, but we don't know what they represent.
from sklearn.cluster import KMeans
import numpy as np

# Notice there are no 'y' labels here!
X_unlabeled = np.array([
    [1.1, 2.0], [1.0, 4.1], [1.2, 0.5], # Cluster A (bottom left)
    [10.2, 2.1], [10.0, 4.0], [10.3, 0.8] # Cluster B (bottom right)
])

# Tell the model to find 2 distinct groups
kmeans = KMeans(n_clusters=2, random_state=42, n_init="auto")
kmeans.fit(X_unlabeled)

print(f"The model grouped the data points as follows:")
print(f"Cluster assignments: {kmeans.labels_}")
print("Done...")

ans = kmeans.predict([[9.2, 2.0]])
print(ans)
ans = kmeans.predict([[9.2, 2.0]])
print(ans)
# Out:
# The model grouped the data points as follows:
# Cluster assignments: [0 0 0 1 1 1]
# Done...
# [1]

# %%
def calculate_monthly_agent_budget(
    daily_active_users: int,
    tasks_per_user_day: int,
    avg_turns_per_task: int,
    avg_input_tokens_per_turn: int,
    avg_output_tokens_per_turn: int,
    input_price_per_million: float,
    output_price_per_million: float,
    cache_read_discount_pct: float = 0.50
) -> dict:
    """Calculates operational economics for enterprise autonomous agents."""
    
    days_per_month = 30
    total_turns_per_month = daily_active_users * tasks_per_user_day * avg_turns_per_task * days_per_month
    
    total_input_tokens = total_turns_per_month * avg_input_tokens_per_turn
    total_output_tokens = total_turns_per_month * avg_output_tokens_per_turn
    
    # Estimate 60% of input tokens are cached system prompts / RAG docs
    cached_input_tokens = total_input_tokens * 0.60
    uncached_input_tokens = total_input_tokens * 0.40
    
    cost_uncached = (uncached_input_tokens / 1_000_000) * input_price_per_million
    cost_cached = (cached_input_tokens / 1_000_000) * (input_price_per_million * (1 - cache_read_discount_pct))
    cost_output = (total_output_tokens / 1_000_000) * output_price_per_million
    
    total_cost = cost_uncached + cost_cached + cost_output
    cost_per_task = total_cost / (daily_active_users * tasks_per_user_day * days_per_month)
    
    return {
        "monthly_turns": total_turns_per_month,
        "total_input_tokens": total_input_tokens,
        "total_output_tokens": total_output_tokens,
        "gross_cost_usd": round(total_cost, 2),
        "cost_per_task_usd": round(cost_per_task, 4)
    }

# Example Enterprise Scenario: 500 Customer Support Reps using an automated triage agent
budget = calculate_monthly_agent_budget(
    daily_active_users=500,
    tasks_per_user_day=15,
    avg_turns_per_task=4,
    avg_input_tokens_per_turn=2500,  # Context includes RAG documents & chat history
    avg_output_tokens_per_turn=400,
    input_price_per_million=0.150,   # e.g., GPT-4o-mini pricing ($0.15 / 1M input)
    output_price_per_million=0.600    # ($0.60 / 1M output)
)

print("\n=== ENTERPRISE AGENT TCO PROJECTION ===")
for key, val in budget.items():
    print(f"  {key.ljust(25)}: {val}")
# Out:
# === ENTERPRISE AGENT TCO PROJECTION ===
#   monthly_turns            : 900000
#   total_input_tokens       : 2250000000
#   total_output_tokens      : 360000000
#   gross_cost_usd           : 452.25
#   cost_per_task_usd        : 0.002
